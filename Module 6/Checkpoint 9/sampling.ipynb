# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import math
from scipy.stats import ttest_ind
# %matplotlib inline

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

# Let’s make histograms for the two groups. 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())
diff=sample2.mean( ) - sample1.mean()
print(diff)
# Out:
# 2.1
# 4.73
# 1.0816653826391966
# 1.6604517457607735
# 2.6300000000000003

# %% [markdown]
# Question 1
# Means values are going to change slightly, the standard deviation are going to change a lot.

# %%
sample11k = np.random.choice(pop1, 1000, replace=True)
sample21k = np.random.choice(pop2, 1000, replace=True)
print(sample11k.mean())
print(sample21k.mean())
print(sample11k.std())
print(sample21k.std())
diff1k=sample21k.mean( ) - sample11k.mean()
print(diff1k)
# Out:
# 2.019
# 4.977
# 1.2126990558254755
# 1.5239655507917493
# 2.958

# %%
plt.hist(sample11k, alpha=0.5, label='sample 1') 
plt.hist(sample21k, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

# %% [markdown]
# Increasing the sample size is a better representation of the actual data.

# %%
sample120 = np.random.choice(pop1, 20, replace=True)
sample220 = np.random.choice(pop2, 20, replace=True)
print(sample120.mean())
print(sample220.mean())
print(sample120.std())
print(sample220.std())
diff20=sample220.mean( ) - sample120.mean()
print(diff20)
# Out:
# 2.25
# 4.9
# 1.0428326807307104
# 0.99498743710662
# 2.6500000000000004

# %%
plt.hist(sample120, alpha=0.5, label='sample 1') 
plt.hist(sample220, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

# %% [markdown]
# Changing the sample size to 20 has lowered the overlap of the two datasets to almost nothing.

# %% [markdown]
# Question 2

# %%
pop1 = np.random.binomial(10, 0.3, 10000)
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)
mean1 = sample1.mean()
mean2 = sample2.mean()
std1 = sample1.std()
std2 = sample2.std()
y = mean2 - mean1
se = math.sqrt(((std1**2)/len(sample1)) + ((std2**2)/len(sample2)))
tval = (y / se)
print(se, y, tval)
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# 0.054664092419064274 -1.6249999999999998 -29.72700959786311
# Ttest_indResult(statistic=-29.71214237532888, pvalue=1.5860700777011285e-155)

# %%
pop1 = np.random.binomial(10, 0.4, 10000)
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)
mean1 = sample1.mean()
mean2 = sample2.mean()
std1 = sample1.std()
std2 = sample2.std()
y = mean2 - mean1
se = math.sqrt(((std1**2)/len(sample1)) + ((std2**2)/len(sample2)))
tval = (y / se)
print(se, y, tval)
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# 0.05736789171653426 -2.5710000000000006 -44.816009845782794
# Ttest_indResult(statistic=-44.79359623605591, pvalue=3.695031975638701e-282)

# %% [markdown]
# The P-val changed slightly but the t-val changed significally.  There has been a big change in the t-value, it has decreased meaning the two means have come closer together, it is probaly do to more of an overlap of values between the two data sets as they become more similar.

# %%
pop1 = np.random.logseries(0.2, 10000)
pop2 = np.random.logseries(0.5, 10000)
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)
mean1 = sample1.mean()
mean2 = sample2.mean()
std1 = sample1.std()
std2 = sample2.std()
y = mean2 - mean1
se = math.sqrt(((std1**2)/len(sample1)) + ((std2**2)/len(sample2)))
tval = (y / se)
print(se, y, tval)
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# 0.19332614929181205 0.55 2.8449333006152946
# Ttest_indResult(statistic=2.772897980579585, pvalue=0.012117510792104009)

# %%
pop1 = np.random.logseries(0.4, 10000)
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)
mean1 = sample1.mean()
mean2 = sample2.mean()
std1 = sample1.std()
std2 = sample2.std()
y = mean2 - mean1
se = math.sqrt(((std1**2)/len(sample1)) + ((std2**2)/len(sample2)))
tval = (y / se)
print(se, y, tval)
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# 0.035421504767584336 0.07499999999999996 2.1173578167304603
# Ttest_indResult(statistic=2.1162988730199497, pvalue=0.03444328919164752)

# %% [markdown]
# I believe that they do, the Central Limit Theorem states that the more samples you take, the average of your sample means will represent the population mean, no matter the distribution we utilize.
