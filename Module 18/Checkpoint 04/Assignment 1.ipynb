# %% [markdown]
# # Assignment 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate annual income as X
X = np.arange(30000, 80000, 1000, dtype='int64')
# The model without kids as Y
Y = 873 + 0.0012*X + 0.000002 * (X ** 2)
# Number of kids as K
K = 3
# The model with 1 kid as Y_1K
Y_Kids = 873 + (0.0012 * X) + (0.000002 * (X ** 2)) - (223.57 * K)


plt1 = plt.plot(X, Y, label='No children')
plt2 = plt.plot(X, Y_Kids, label='With {} Children'.format(K))
plt.title('Income vs Recreational Spending')
plt.xlabel('Income')
plt.ylabel('Recreational Spending')
plt.legend()
plt.show()

# %% [markdown]
# The annual income has a significant effect on the expenditure, it is of statistical significance.  The dummy variable of children will have little to no effect on the outcome of expenditure, as families will reach a maximum potential on the ammount of children they can have.  The length of vacation would be a useful statistic for this model.
